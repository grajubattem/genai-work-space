# %%
import pandas as pd

# %%
import numpy as np

# %%
# !pip install gensim

# %%
temp_df = pd.read_csv('IMDB.csv')

# %%
temp_df.head()
# Out:
#   review\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t
# 0  One of the other reviewers has mentioned that ...
# 1  A wonderful little production. <br /><br />The...
# 2  I thought this was a wonderful way to spend ti...
# 3  Basically there's a family where a little boy ...
# 4  Petter Mattei's "Love in the Time of Money" is...

# %%
temp_df.rename(columns={'review\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t': 'review'}, inplace=True)

# %%
temp_df.head()
# Out:
#                                               review
# 0  One of the other reviewers has mentioned that ...
# 1  A wonderful little production. <br /><br />The...
# 2  I thought this was a wonderful way to spend ti...
# 3  Basically there's a family where a little boy ...
# 4  Petter Mattei's "Love in the Time of Money" is...

# %%
# !pip install xlrd

# %%
temp_df.head()
# Out:
#                                               review
# 0  One of the other reviewers has mentioned that ...
# 1  A wonderful little production. <br /><br />The...
# 2  I thought this was a wonderful way to spend ti...
# 3  Basically there's a family where a little boy ...
# 4  Petter Mattei's "Love in the Time of Money" is...

# %%
temp_df.rename(columns={'old_column_name': 'new_column_name'}, inplace=True)

# %%
temp_df.rename(columns={'review\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t': 'review'}, inplace=True)

# %%
temp_df.head()
# Out:
#                                               review
# 0  One of the other reviewers has mentioned that ...
# 1  A wonderful little production. <br /><br />The...
# 2  I thought this was a wonderful way to spend ti...
# 3  Basically there's a family where a little boy ...
# 4  Petter Mattei's "Love in the Time of Money" is...

# %%
temp_df.drop_duplicates()
# Out:
#                                                   review
# 0      One of the other reviewers has mentioned that ...
# 1      A wonderful little production. <br /><br />The...
# 2      I thought this was a wonderful way to spend ti...
# 3      Basically there's a family where a little boy ...
# 4      Petter Mattei's "Love in the Time of Money" is...
# ...                                                  ...
# 49994  This is your typical junk comedy.<br /><br />T...
# 49995  I thought this movie did a down right good job...
# 49997  I am a Catholic taught in parochial elementary...
# 49998  I'm going to have to disagree with the previou...
# 49999  No one expects the Star Trek movies to be high...
#
# [47255 rows x 1 columns]

# %%
import re
def remove_tags(raw_text):
    cleaned_text = re.sub(re.compile('<.*?>'), '', raw_text)
    return cleaned_text
 
temp_df['review'] = temp_df['review'].apply(remove_tags)

# %%
temp_df.head()
# Out:
#                                               review
# 0  One of the other reviewers has mentioned that ...
# 1  A wonderful little production. The filming tec...
# 2  I thought this was a wonderful way to spend ti...
# 3  Basically there's a family where a little boy ...
# 4  Petter Mattei's "Love in the Time of Money" is...

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
 
sw_list = stopwords.words('english')
 
temp_df['review'] = temp_df['review'].apply(lambda x: [item for item in x.split() if item not in sw_list]).apply(lambda x:" ".join(x))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\graju\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
temp_df.head()
# Out:
#                                               review
# 0  One reviewers mentioned watching 1 Oz episode ...
# 1  A wonderful little production. The filming tec...
# 2  I thought wonderful way spend time hot summer ...
# 3  Basically there's family little boy (Jake) thi...
# 4  Petter Mattei's "Love Time Money" visually stu...

# %%
print(stopwords.words('english'))
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %%
import gensim
from nltk import sent_tokenize
from gensim.utils import simple_preprocess
 
story = []
for doc in temp_df['review']:
    raw_sent = sent_tokenize(doc)
    for sent in raw_sent:
        story.append(simple_preprocess(sent))
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[22], line 7
#       5 story = []
#       6 for doc in temp_df['review']:
# ----> 7     raw_sent = sent_tokenize(doc)
#       8     for sent in raw_sent:
#       9         story.append(simple_preprocess(sent))
#
# File ~\anaconda3\Lib\site-packages\nltk\tokenize\__init__.py:119, in sent_tokenize(text, language)
#     109 def sent_tokenize(text, language="english"):
#     110     """
#     111     Return a sentence-tokenized copy of *text*,
#     112     using NLTK's recommended sentence tokenizer
#    (...)
#     117     :param language: the model name in the Punkt corpus
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
#     120     return tokenizer.tokenize(text)
#
# File ~\anaconda3\Lib\site-packages\nltk\tokenize\__init__.py:105, in _get_punkt_tokenizer(language)
#      96 @functools.lru_cache
# ...

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\graju\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
import gensim
from nltk import sent_tokenize
from gensim.utils import simple_preprocess
 
story = []
for doc in temp_df['review']:
    raw_sent = sent_tokenize(doc)
    for sent in raw_sent:
        story.append(simple_preprocess(sent))

# %%
story
# Out:
# [['one', 'reviewers', 'mentioned', 'watching', 'oz', 'episode', 'hooked'],
#  ['they', 'right'],
#  ['wonderful', 'little', 'production'],
#  ['the',
#   'filming',
#   'technique',
#   'unassuming',
#   'old',
#   'time',
#   'bbc',
#   'fashion',
#   'gives',
#   'comforting'],
#  ['thought', 'wonderful', 'way', 'spend', 'time', 'hot', 'summer', 'weekend'],
#  ['basically',
#   'there',
#   'family',
#   'little',
#   'boy',
#   'jake',
#   'thinks',
#   'there',
#   'zombie',
#   'closet',
#   'parents',
#   'fighting',
#   'time',
#   'this',
#   'movie',
#   'slower',
#   'soap',
#   'opera',
#   'suddenly'],
#  ['petter',
#   'mattei',
#   'love',
#   'time',
#   'money',
#   'visually',
#   'stunning',
#   'film',
#   'watch'],
#  ['mr', 'mattei', 'offers', 'us', 'vivid', 'portrait', 'human', 'relations'],
#  ['this', 'movie', 'seems', 'telling', 'us', 'money'],
#  ['probably', 'all', 'time', 'favorite', 'movie'],
#  ['sure',
#   'would',
#   'like',
#   'see',
# ...

# %%
model = gensim.models.Word2Vec(
    window=10,
    min_count=2
)
 
model.build_vocab(story)

# %%
model.train(story, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# (3660811, 4088595)

# %%
import numpy as np
def document_vector(doc):
    # remove out-of-vocabulary words
    doc = [word for word in doc.split() if word in model.wv.index_to_key]
    return np.mean(model.wv[doc], axis=0)
 
 
document_vector(temp_df['review'].values[0])
# Out:
# array([-0.06018329, -0.3137509 ,  0.39701012,  0.08947529, -0.3672194 ,
#        -0.19965267, -0.0178692 ,  1.1066586 , -0.20733857, -0.21584693,
#         0.04903058, -0.7654136 , -0.16079053,  0.00886075, -0.30151644,
#        -0.3911053 ,  0.5602845 , -0.6277479 , -0.00525266, -0.84682643,
#         0.10003074,  0.6662942 ,  0.50450814,  0.10947108,  0.08200929,
#         0.5158899 , -0.38891932, -0.31197798, -0.0339662 , -0.13165276,
#         0.6749148 , -0.06434815,  0.4989387 , -0.39702612, -0.26801157,
#         0.80072606,  0.25596124, -1.13329   , -0.48230353, -0.7339283 ,
#         0.27555794, -0.30536956, -0.03827313, -0.01817274,  0.46116433,
#        -0.49072194, -0.30646673, -0.26663035,  0.0875717 ,  0.20727679,
#         0.20959333, -0.5223759 , -0.49541777, -0.06281308, -0.43743008,
#         0.283964  , -0.00764416,  0.01103411, -0.3449373 ,  0.03509546,
#         0.15716472, -0.28490034,  0.7006775 , -0.17729726, -0.6349465 ,
# ...
